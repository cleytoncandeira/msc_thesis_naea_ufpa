# %%
import sys
sys.path.append('/home/cleyton/ProjetosGit/air_quality_mapper')

# %%
api = {"GOOGLE_MAPS_API_KEY": 'AIzaSyCTNXDFj2A73fuTjTJS3-A_ytQEYKtlhBM'}

# %%
import leafmap.foliumap as leafmap
import folium
from air_pollution_mapper.api_caller.Client import Client
from air_pollution_mapper.api_caller.air_quality_heatmap_tile import air_quality_tile
#from air_pollution_mapper.api_caller.utils import load_secrets
from air_pollution_mapper.constants import MAPS_DUMP_DIR
import os
# Out:
# Please restart Jupyter kernel after installation if you encounter any errors when importing leafmap.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/ProjetosGit/venv/lib/python3.11/site-packages/leafmap/__init__.py:32
#      31 try:
# ---> 32     from .leafmap import *
#      33 except Exception as e:
#
# File ~/ProjetosGit/venv/lib/python3.11/site-packages/leafmap/leafmap.py:8
#       7 from IPython.display import display
# ----> 8 from .basemaps import xyz_to_leaflet
#       9 from .common import *
#
# File ~/ProjetosGit/venv/lib/python3.11/site-packages/leafmap/basemaps.py:24
#      23 import requests
# ---> 24 import folium
#      25 import ipyleaflet
#
# File ~/ProjetosGit/venv/lib/python3.11/site-packages/folium/__init__.py:3
#       1 import sys
# ----> 3 import branca
#       4 from branca.colormap import ColorMap, LinearColormap, StepColormap
#
# File ~/ProjetosGit/venv/lib/python3.11/site-packages/branca/__init__.py:1
# ----> 1 import branca.colormap as colormap
#       2 import branca.element as element
#
# File ~/ProjetosGit/venv/lib/python3.11/site-packages/branca/colormap.py:13
#      11 import os
# ---> 13 from jinja2 import Template
#      15 from branca.element import ENV, Figure, JavascriptLink, MacroElement
#
# File ~/ProjetosGit/venv/lib/python3.11/site-packages/jinja2/__init__.py:12
#      11 from .bccache import MemcachedBytecodeCache
# ---> 12 from .environment import Environment
#      13 from .environment import Template
#
# File ~/ProjetosGit/venv/lib/python3.11/site-packages/jinja2/environment.py:25
#      24 from .compiler import generate
# ---> 25 from .defaults import BLOCK_END_STRING
#      26 from .defaults import BLOCK_START_STRING
#
# File ~/ProjetosGit/venv/lib/python3.11/site-packages/jinja2/defaults.py:3
#       2 from ._compat import range_type
# ----> 3 from .filters import FILTERS as DEFAULT_FILTERS  # noqa: F401
#       4 from .tests import TESTS as DEFAULT_TESTS  # noqa: F401
#
# File ~/ProjetosGit/venv/lib/python3.11/site-packages/jinja2/filters.py:13
#      12 from markupsafe import Markup
# ---> 13 from markupsafe import soft_unicode
#      15 from ._compat import abc
#
# ImportError: cannot import name 'soft_unicode' from 'markupsafe' (/home/cleyton/ProjetosGit/venv/lib/python3.11/site-packages/markupsafe/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /home/cleyton/ProjetosGit/msc_thesis_naea_ufpa/3_GetGeoData/test_notebook.ipynb Célula 3 line 1
# ----> <a href='vscode-notebook-cell:/home/cleyton/ProjetosGit/msc_thesis_naea_ufpa/3_GetGeoData/test_notebook.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> import leafmap.foliumap as leafmap
#       <a href='vscode-notebook-cell:/home/cleyton/ProjetosGit/msc_thesis_naea_ufpa/3_GetGeoData/test_notebook.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> import folium
#       <a href='vscode-notebook-cell:/home/cleyton/ProjetosGit/msc_thesis_naea_ufpa/3_GetGeoData/test_notebook.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> from air_pollution_mapper.api_caller.Client import Client
#
# File ~/ProjetosGit/venv/lib/python3.11/site-packages/leafmap/__init__.py:42
#      38         else:
#      39             print(
#      40                 "Please restart Jupyter kernel after installation if you encounter any errors when importing leafmap."
#      41             )
# ---> 42         raise Exception(e)
#      45 from .report import Report
#
# Exception: cannot import name 'soft_unicode' from 'markupsafe' (/home/cleyton/ProjetosGit/venv/lib/python3.11/site-packages/markupsafe/__init__.py)

# %%
def main():
    secrets = api['GOOGLE_MAPS_API_KEY']
    client = Client(key=secrets["GOOGLE_MAPS_API_KEY"])

    # get the lat, lon and zoom
    zoom = 7
    lat = 37.8
    lon = -121.8

    location = {"latitude": lat, "longitude": lon}

    # get the tiles
    tiles = air_quality_tile(
        client,
        location,
        pollutant="US_AQI",
        zoom=zoom,
        get_adjoining_tiles=True,
    )

    map = leafmap.Map(location=[lat, lon], tiles="OpenStreetMap", zoom_start=zoom)

    #add all the tiles that we just made
    for tile in tiles:
        latmin, latmax, lonmin, lonmax = tile["bounds"]
        AQ_image = tile["image"]
        folium.raster_layers.ImageOverlay(
        image=AQ_image, bounds=[[latmin, lonmin], [latmax, lonmax]], opacity=0.8
        ).add_to(map)

    # save to test location
    map.to_html(os.path.join(MAPS_DUMP_DIR, "test_air_quality.html"))

# %%
tiles
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/cleyton/ProjetosGit/msc_thesis_naea_ufpa/3_GetGeoData/test_notebook.ipynb Célula 5 line 1
# ----> <a href='vscode-notebook-cell:/home/cleyton/ProjetosGit/msc_thesis_naea_ufpa/3_GetGeoData/test_notebook.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> tiles
#
# NameError: name 'tiles' is not defined
