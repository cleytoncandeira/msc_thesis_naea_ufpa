# %% [markdown]
# # Step 1 -- Extract PDFs files from RTRS web Site

# %%
import requests, os, re, copy, io
import pandas as pd
from PyPDF2 import PdfFileReader
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By 
from time import sleep

options = webdriver.ChromeOptions()

options.add_argument('user-data-dir=Perfil')
#options.add_argument('--headless')

navegador = webdriver.Chrome(
            'chromedriver',
            options=options)

navegador.get('https://responsiblesoy.org/public-audit-reports?lang=en')

navegador.find_element(By.CLASS_NAME, 'zyxaudit-btn_buscar').click()

sleep(2)

#integrate bs4 and Selenium (when Vegeta and Goku merge!)

web_html = BeautifulSoup(navegador.page_source, 'html.parser')

navegador.quit()

audit_general_data = web_html.find('div', attrs={'class': 
                                              'zyxaudit-buscador_results vc_col-xs-12 col-xs-12 zyxaudit-results-active'})

names = []
country = []
year = []
links = []

labels = ['vc_col-md-6 vc_col-xs-12 zyxaudit-nombre_empresa',
         'vc_col-md-2 vc_col-xs-12 zyxaudit-pais', 
         'vc_col-md-2 vc_col-xs-12 zyxaudit-anio', ]

for clas in labels:
    for audit in audit_general_data:
        temp = audit.find('div', attrs = {'class':clas})
        if clas.endswith('nombre_empresa'):
            names.append(temp.text)
        elif clas.endswith('pais'):
            country.append(temp.text)
        else:
            year.append(temp.text)
            
#links to download audit reports             
a_tags = audit_general_data.find_all('a', href = True)

for tag in a_tags:
    links.append(tag['href'])        

#create a data frame obj

certified_producers_rtrs = pd.DataFrame(list(zip(names[1:326],
                                                country[1:326],
                                                year[1:326],
                                                links)), 
                                        columns = ['Names', 'Country', 'Year', 'Links'])

certified_producers_rtrs['Year'] = pd.to_numeric(certified_producers_rtrs['Year'])

certified_producers_rtrs.to_csv('certified_producers_rtrs.csv')

# %%
#Dowload all reports from RTRS web site!

#Problem: it's so lazy! 

i = 0

for link in links:
    i += 1
    response = requests.get(link)
    with open('audit_reports/audit_report_rtrs'+str(i)+'.pdf', 'wb') as PdfObj:
        PdfObj.write(response.content)
        print("File ", i, " downloaded")
    
print("All PDF files downloaded!")
# Out:
# File  1  downloaded
# File  2  downloaded
# File  3  downloaded
# File  4  downloaded
# File  5  downloaded
# File  6  downloaded
# File  7  downloaded
# File  8  downloaded
# File  9  downloaded
# File  10  downloaded
# File  11  downloaded
# File  12  downloaded
# File  13  downloaded
# File  14  downloaded
# File  15  downloaded
# File  16  downloaded
# File  17  downloaded
# File  18  downloaded
# File  19  downloaded
# File  20  downloaded
# File  21  downloaded
# File  22  downloaded
# File  23  downloaded
# File  24  downloaded
# File  25  downloaded
# File  26  downloaded
# File  27  downloaded
# File  28  downloaded
# File  29  downloaded
# File  30  downloaded
# File  31  downloaded
# File  32  downloaded
# File  33  downloaded
# File  34  downloaded
# File  35  downloaded
# File  36  downloaded
# File  37  downloaded
# File  38  downloaded
# File  39  downloaded
# File  40  downloaded
# File  41  downloaded
# File  42  downloaded
# File  43  downloaded
# File  44  downloaded
# File  189  downloaded
# File  190  downloaded
# File  191  downloaded
# File  192  downloaded
# File  193  downloaded
# File  194  downloaded
# File  195  downloaded
# File  196  downloaded
# File  197  downloaded
# File  198  downloaded
# File  199  downloaded
# File  200  downloaded
# File  201  downloaded
# File  202  downloaded
# File  203  downloaded
# File  204  downloaded
# File  205  downloaded
# File  206  downloaded
# File  207  downloaded
# File  208  downloaded
# File  209  downloaded
# File  210  downloaded
# File  211  downloaded
# File  212  downloaded
# File  213  downloaded
# File  214  downloaded
# File  215  downloaded
# File  216  downloaded
# File  217  downloaded
# File  218  downloaded
# File  219  downloaded
# File  220  downloaded
# File  221  downloaded
# File  222  downloaded
# File  223  downloaded
# File  224  downloaded
# File  225  downloaded
# File  226  downloaded
# File  227  downloaded
# File  228  downloaded
# File  229  downloaded
# File  230  downloaded
# File  231  downloaded
# File  232  downloaded
# File  233  downloaded
# File  234  downloaded
# File  235  downloaded
# File  236  downloaded
# File  237  downloaded
# File  238  downloaded
# File  239  downloaded
# File  240  downloaded
# File  241  downloaded
# File  242  downloaded
# File  243  downloaded
# File  244  downloaded
# File  245  downloaded
# File  246  downloaded
# File  247  downloaded
# File  248  downloaded
# File  249  downloaded
# File  250  downloaded
# File  251  downloaded
# File  252  downloaded
# File  253  downloaded
# File  254  downloaded
# File  255  downloaded
# File  256  downloaded
# File  257  downloaded
# File  258  downloaded
# File  259  downloaded
# File  260  downloaded
# File  261  downloaded
# File  262  downloaded
# File  263  downloaded
# File  264  downloaded
# File  265  downloaded
# File  266  downloaded
# File  267  downloaded
# File  268  downloaded
# File  269  downloaded
# File  270  downloaded
# File  271  downloaded
# File  272  downloaded
# File  273  downloaded
# File  274  downloaded
# File  275  downloaded
# File  276  downloaded
# File  277  downloaded
# File  278  downloaded
# File  279  downloaded
# File  280  downloaded
# File  281  downloaded
# File  282  downloaded
# File  283  downloaded
# File  284  downloaded
# File  285  downloaded
# File  286  downloaded
# File  287  downloaded
# File  288  downloaded
# File  289  downloaded
# File  290  downloaded
# File  291  downloaded
# File  292  downloaded
# File  293  downloaded
# File  294  downloaded
# File  295  downloaded
# File  296  downloaded
# File  297  downloaded
# File  298  downloaded
# File  299  downloaded
# File  300  downloaded
# File  301  downloaded
# File  302  downloaded
# File  303  downloaded
# File  304  downloaded
# File  305  downloaded
# File  306  downloaded
# File  307  downloaded
# File  308  downloaded
# File  309  downloaded
# File  310  downloaded
# File  311  downloaded
# File  312  downloaded
# File  313  downloaded
# File  314  downloaded
# File  315  downloaded
# File  316  downloaded
# File  317  downloaded
# File  318  downloaded
# File  319  downloaded
# File  320  downloaded
# File  321  downloaded
# File  322  downloaded
# File  323  downloaded
# File  324  downloaded
# File  325  downloaded
# All PDF files downloaded!

# %%
#We can performer the download with ThreadPoolExecutor

import concurrent.futures

pool = ThreadPoolExecutor(max_workers = 30)
