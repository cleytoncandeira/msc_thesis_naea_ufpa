# %% [markdown]
# ## Pre-Processing DataBase Loader
#
# A idéia desse notebook é criar uma base de dados no formato Torch para os arquivos em pdf, junto com uma pré-classificação de treino/teste como pré-processamento do `LayoutLMv3`.
#
# - A primeira atividade é converter os arquivos pdfs em imagens `.jpg`, similar à organização de um dataset de cats vs dogs (competição clássica do Kaggle para Redes Neurais Convolucionais)
# - A segunda atividade é classificar os relatórios enquanto um diretório acima por empresas de auditoria (**Third Party**)
# - A terceira atividade é usar o `OpenCV` para delimitar os `blinding boxs` nas áreas de cada página de arquivo `.jpg` , declarar seu respectivo label e enriquecer com variáveis, para cada relatório em subdiretórios classificados por empresa de auditoria (**Third Party**)

# %% [markdown]
# ### passo 1: converter pdfs para imagens

# %%
from pathlib import Path
from pdf2image import convert_from_path
from tqdm import tqdm

# %%
import os
from pdf2image import convert_from_path
from tqdm import tqdm

def convert_pdfs_to_images(pdf_directory, output_directory, dpi=120):
    """
    Converte um conjunto de PDFs em imagens, armazenando as páginas de cada PDF em subdiretórios separados.

    Args:
        pdf_directory (str): Caminho para o diretório contendo os arquivos PDF.
        output_directory (str): Caminho para o diretório onde os subdiretórios e imagens serão armazenados.
        dpi (int): Resolução das imagens geradas (padrão: 150 DPI).
    """
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    pdf_files = [f for f in os.listdir(pdf_directory) if f.lower().endswith('.pdf')]

    for pdf_file in tqdm(pdf_files, desc="Convertendo PDFs", unit="arquivo"):
        pdf_path = os.path.join(pdf_directory, pdf_file)

        pdf_name = os.path.splitext(pdf_file)[0]
        pdf_output_dir = os.path.join(output_directory, pdf_name)
        os.makedirs(pdf_output_dir, exist_ok=True)

        try:
            images = convert_from_path(pdf_path, dpi=dpi)

            for page_number, image in enumerate(tqdm(images, desc=f"Processando {pdf_file}", unit="página", leave=False), start=1):
                image_filename = f"page_{page_number}.jpg"
                image_path = os.path.join(pdf_output_dir, image_filename)
                image.save(image_path, 'JPEG')

        except Exception as e:
            print(f"Erro ao processar o arquivo '{pdf_file}': {e}")

# %%
ROOT = Path.cwd().parent.parent
RAW_PDF = ROOT / 'data' / 'external_data' / 'audit_reports'
PROCESSED_PDF = ROOT / 'data' / 'processed_data' / 'audit_reports_database'

# %%
print(PROCESSED_PDF.parent)
# Out:
# /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data

# %%
convert_pdfs_to_images(pdf_directory=RAW_PDF, output_directory=PROCESSED_PDF)
# Out:
# Convertendo PDFs: 100%|██████████| 244/244 [03:34<00:00,  1.14arquivo/s]

# %% [markdown]
# ### passo 2: classificar os relatórios em um diretório acima de acordo com as empresas de auditoria

# %%
import shutil
import re
from PIL import Image
import pytesseract

# %%
# Regex para identificar as empresas 
EMPRESA_REGEX = {
    "Food Chain ID": r"\b[Ff]ood\s*[Cc]hain\s*[Ii][Dd]\b",
    "Control Union": r"\b[Cc]ontrol\s*[Uu]nion\b",
    "Genesis Certificações": r"\b[Gg]enesis\s\b",
    "Bureau Veritas": r"\b[Bb]ureau\s*[Vv]eritas\b",
    "SGS Argentina": r"\b[SGS]{3}\s*[Aa]rgentina\b",
    "Cert ID": r"\b[Cc]ert\s*[Ii][Dd]\b",
}


ORGANIZED_PDF = PROCESSED_PDF.parent / 'organized_audit_reports'

# %%
os.makedirs(ORGANIZED_PDF, exist_ok=True)

def identificar_empresa(texto):
    for empresa, regex in EMPRESA_REGEX.items():
        if re.search(regex, texto, re.IGNORECASE):
            return empresa
    return None

# %%
def processar_relatorio(relatorio_path):
    texto_total = ""
    for imagem in os.listdir(relatorio_path):
        imagem_path = os.path.join(relatorio_path, imagem)
        if imagem.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.bmp')):
            try:
                # Extrair texto da imagem usando Tesseract
                texto = pytesseract.image_to_string(Image.open(imagem_path))
                texto_total += texto + "\n"
            except Exception as e:
                print(f"Erro ao processar {imagem_path}: {e}")
    return texto_total

# %%
relatorios = [relatorio for relatorio in os.listdir(PROCESSED_PDF) if os.path.isdir(os.path.join(PROCESSED_PDF, relatorio))]
for relatorio in tqdm(relatorios, desc="Classificando relatórios"):
    relatorio_path = os.path.join(PROCESSED_PDF, relatorio)
    
    texto_relatorio = processar_relatorio(relatorio_path)
    empresa = identificar_empresa(texto_relatorio)
    
    if empresa:
        empresa_dir = os.path.join(ORGANIZED_PDF, empresa)
        os.makedirs(empresa_dir, exist_ok=True)

        shutil.move(relatorio_path, os.path.join(empresa_dir, relatorio))
    else:
        print(f"Empresa não identificada para: {relatorio}")
# Out:
# Classificando relatórios:  39%|███▉      | 19/49 [06:14<11:32, 23.07s/it]
# Empresa não identificada para: audit_report_rtrs67
# Classificando relatórios:  61%|██████    | 30/49 [10:02<07:05, 22.42s/it]
# Empresa não identificada para: audit_report_rtrs68
# Classificando relatórios:  78%|███████▊  | 38/49 [12:44<04:01, 22.00s/it]
# Empresa não identificada para: audit_report_rtrs219
# Classificando relatórios:  90%|████████▉ | 44/49 [15:00<02:18, 27.75s/it]
# Empresa não identificada para: audit_report_rtrs87
# Classificando relatórios:  98%|█████████▊| 48/49 [16:48<00:29, 29.84s/it]
# Empresa não identificada para: audit_report_rtrs85
# Classificando relatórios: 100%|██████████| 49/49 [17:11<00:00, 21.06s/it]

# %% [markdown]
# ### passo 3: conhecendo a distribuição das classes

# %%
#função para contar o número de subdiretórios (relatórios) por classe
def contar_relatorios(base_dir):
    classes = {}
    for empresa in os.listdir(base_dir):
        empresa_path = os.path.join(base_dir, empresa)
        if os.path.isdir(empresa_path):
            relatorios = [item for item in os.listdir(empresa_path) if os.path.isdir(os.path.join(empresa_path, item))]
            classes[empresa] = len(relatorios)
    return classes

#função para calcular o número mínimo de relatórios por classe
def estimar_relatorios_minimos(classes, min_relatorios=5):
    relatorios_insuficientes = {classe: count for classe, count in classes.items() if count < min_relatorios}
    return relatorios_insuficientes

# %%
classes_contagem = contar_relatorios(ORGANIZED_PDF)
minimo_relatorios = 5  
relatorios_insuficientes = estimar_relatorios_minimos(classes_contagem, minimo_relatorios)

print("Contagem de relatórios por classe:")
for classe, count in classes_contagem.items():
    print(f"{classe}: {count} relatórios")

print("\nClasses com relatórios insuficientes:")
if relatorios_insuficientes:
    for classe, count in relatorios_insuficientes.items():
        print(f"{classe}: {count} (necessário: {minimo_relatorios})")
else:
    print("Todas as classes possuem relatórios suficientes.")
# Out:
# Contagem de relatórios por classe:
# Control Union: 103 relatórios
# SGS Argentina: 2 relatórios
# Food Chain ID: 82 relatórios
# Genesis Certificações: 44 relatórios
# Bureau Veritas: 6 relatórios
# Cert ID: 2 relatórios
#
# Classes com relatórios insuficientes:
# SGS Argentina: 2 (necessário: 5)
# Cert ID: 2 (necessário: 5)

# %% [markdown]
# ### passo 4: selecionando amostras e construir os arquivos json

# %%
import cv2

# %%
boxes = []
drawing = False
ix, iy = -1, -1
scale_percent = 50  #reduz a imagem para 50% do tamanho original -- obs: a tela do meu pc é pequena

# Função de callback para desenhar bounding boxes
def draw_bbox(event, x, y, flags, param):
    global ix, iy, drawing, boxes, img_resized, img_copy_resized

    if event == cv2.EVENT_LBUTTONDOWN:
        drawing = True
        ix, iy = x, y

    elif event == cv2.EVENT_MOUSEMOVE:
        if drawing:
            img_copy_resized = img_resized.copy()
            cv2.rectangle(img_copy_resized, (ix, iy), (x, y), (0, 255, 0), 2)

    elif event == cv2.EVENT_LBUTTONUP:
        drawing = False
        x_min, y_min = min(ix, x), min(iy, y)
        x_max, y_max = max(ix, x), max(iy, y)
        
        original_bbox = [
            int(x_min / scale_percent * 100),
            int(y_min / scale_percent * 100),
            int(x_max / scale_percent * 100),
            int(y_max / scale_percent * 100),
        ]
        boxes.append(original_bbox)
        cv2.rectangle(img_copy_resized, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
        print(f"BBox salva: {original_bbox}")

# Função principal para processar uma imagem
def processar_imagem(image_path: Path, label: str):
    global img, img_resized, img_copy_resized, boxes

    boxes = []

    img = cv2.imread(str(image_path))
    if img is None:
        print(f"Erro ao carregar a imagem: {image_path}")
        return None

    #redimensiona a imagem para caber na tela
    width = int(img.shape[1] * scale_percent / 100)
    height = int(img.shape[0] * scale_percent / 100)
    img_resized = cv2.resize(img, (width, height), interpolation=cv2.INTER_AREA)
    img_copy_resized = img_resized.copy()

    cv2.namedWindow("image")
    cv2.setMouseCallback("image", draw_bbox)

    print("Pressione 'q' para sair.")
    while True:
        cv2.imshow("image", img_copy_resized)
        key = cv2.waitKey(1) & 0xFF
        if key == ord("q"):  #sair com 'q'
            break

    cv2.destroyAllWindows()

    return [{"bbox": bbox, "label": label} for bbox in boxes]

# %%
image_path = ORGANIZED_PDF / 'Control Union' / 'audit_report_rtrs4' / 'page_1.jpg'  
label = "endereço" 
dados = processar_imagem(image_path, label)
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/cleyton/.local/lib/python3.10/site-packages/cv2/qt/plugins"
# Pressione 'q' para sair.
# BBox salva: [360, 686, 886, 735]

# %%
variaveis = [
    'endereço',
    'cod_certificado',
    'validade_certificado',
    'nome_organização',
    'tipo_avaliacao',
    'area_total',
    'producao',
    'data_prox_auditoria',
    'criterio_1_1',
    'criterio_1_2',
    'criterio_1_3',
    'criterio_2_1',
    'criterio_2_2',
    'criterio_2_3',
    'criterio_2_4',
    'criterio_2_5',
    'criterio_3_1',
    'criterio_3_2',
    'criterio_3_3',
    'criterio_3_4',
    'criterio_4_1',
    'criterio_4_2',
    'criterio_4_3',
    'criterio_4_4',
    'criterio_4_5',
    'criterio_5_1',
    'criterio_5_2',
    'criterio_5_3',
    'criterio_5_4',
    'criterio_5_5',
    'criterio_5_6',
    'criterio_5_7',
    'criterio_5_8',
    'criterio_5_9',
    'criterio_5_10',
    'criterio_5_11',
    'conformidade?',
]

# %%
limite_classificacao = {
    "Control Union": 10,
    "SGS Argentina": 2,
    "Food Chain ID": 10,
    "Genesis Certificações": 3,
    "Bureau Veritas": 3,
    "Cert ID": 2,
}

# %%
import json
import time

def ordenar_paginas_numericamente(paginas):
    def extrair_numero(arquivo):
        match = re.search(r'(\d+)', arquivo.name)
        return int(match.group(1)) if match else float('inf')  
    return sorted(paginas, key=extrair_numero)


# Função que processa cada relatório individualmente
def processar_relatorio(relatorio_path, variaveis):
    resultados = {}
    paginas = ordenar_paginas_numericamente(relatorio_path.glob("*.jpg"))  # Ordenar numericamente

    for variavel in variaveis:
        print(f"Extraindo variável: {variavel}")
        pagina = input(f"Escolha a página (1-{len(paginas)}) para a variável '{variavel}': ")
        pagina_index = int(pagina) - 1

        if pagina_index < 0 or pagina_index >= len(paginas):
            print("Página inválida, pulando variável.")
            continue

        img_path = paginas[pagina_index]
        print(f"Processando imagem: {img_path}")

        dados = processar_imagem(img_path, variavel)
        if dados:
            resultados[variavel] = {"bbox": dados[0]["bbox"], "pagina": str(img_path.name)}
        else:
            print(f"Nenhum bounding box definido para '{variavel}', pulando.")

        time.sleep(2)

    return resultados


# Função que processa várias empresas e seus relatórios
def processar_empresas(base_dir, variaveis, limite_classificacao):
    """
    base_dir: Path para a pasta onde estão as subpastas de empresas.
    variaveis: lista de variáveis que você deseja extrair.
    limite_classificacao: dicionário { 'nome_da_empresa': quantidade_de_relatorios_a_processar }
    """
    for empresa, limite in limite_classificacao.items():
        empresa_dir = base_dir / empresa
        if not empresa_dir.exists():
            print(f"Diretório da empresa '{empresa}' não encontrado. Pulando.")
            continue

        relatorios = sorted(empresa_dir.iterdir())

        for i, relatorio in enumerate(relatorios[:limite]):
            output_path = relatorio / f"{relatorio.name}.json"

            if output_path.exists():
                print(f"Arquivo JSON já existe para '{relatorio.name}', pulando.")
                continue

            print(f"\n[Empresa: {empresa}] Processando relatório {i + 1}/{limite}: {relatorio.name}")
            resultados = processar_relatorio(relatorio, variaveis)

            output_path.parent.mkdir(parents=True, exist_ok=True)

            with open(output_path, "w", encoding="utf-8") as f:
                json.dump(resultados, f, indent=4, ensure_ascii=False)

            print(f"Resultados salvos em: {output_path}")

# %%
processar_empresas(PROCESSED_PDF, variaveis, limite_classificacao)
# Out:
# [Empresa: Cert ID] Processando relatório 1/2: audit_report_rtrs242
# Extraindo variável: endereço
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 processar_empresas(base_dir, variaveis, limite_classificacao)
#
# Cell In[14], line 62, in processar_empresas(base_dir, variaveis, limite_classificacao)
#      59     continue
#      61 print(f"\n[Empresa: {empresa}] Processando relatório {i + 1}/{limite}: {relatorio.name}")
# ---> 62 resultados = processar_relatorio(relatorio, variaveis)
#      64 output_path.parent.mkdir(parents=True, exist_ok=True)
#      66 with open(output_path, "w", encoding="utf-8") as f:
#
# Cell In[14], line 19, in processar_relatorio(relatorio_path, variaveis)
#      17 print(f"Extraindo variável: {variavel}")
#      18 pagina = input(f"Escolha a página (1-{len(paginas)}) para a variável '{variavel}': ")
# ---> 19 pagina_index = int(pagina) - 1
#      21 if pagina_index < 0 or pagina_index >= len(paginas):
#      22     print("Página inválida, pulando variável.")
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ### passo 5: criando o dataset
# - fazer o ocr de cada página com bbox
# - alinhar os tokens retornados do ocr com os bbox do json
# - gerar um dataset token-level (BIO tagging)

# %%
#funções auxiliares

def load_json(json_path):
    """Carrega um arquivo JSON e retorna o dicionário."""
    with open(json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)
    return data

def compute_iou(bbox1, bbox2):
    """
    Calcula a IOU (Interseção sobre União) entre dois bounding boxes.
    bbox em formato [x1, y1, x2, y2].
    Retorna valor entre 0 e 1.
    """
    x1, y1, x2, y2 = bbox1
    x1b, y1b, x2b, y2b = bbox2

    inter_x1 = max(x1, x1b)
    inter_y1 = max(y1, y1b)
    inter_x2 = min(x2, x2b)
    inter_y2 = min(y2, y2b)

    if inter_x2 < inter_x1 or inter_y2 < inter_y1:
        return 0.0

    inter_area = (inter_x2 - inter_x1) * (inter_y2 - inter_y1)
    area1 = (x2 - x1) * (y2 - y1)
    area2 = (x2b - x1b) * (y2b - y1b)
    iou = inter_area / float(area1 + area2 - inter_area)
    return iou

def bbox_center_in(bbox_token, bbox_field):
    """
    Verifica se o centro do token está dentro do bbox_field.
    (Alternativa à IOU para decidir se o token está dentro do campo)
    """
    x1, y1, x2, y2 = bbox_token
    xf1, yf1, xf2, yf2 = bbox_field

    cx = (x1 + x2) / 2
    cy = (y1 + y2) / 2

    return (xf1 <= cx <= xf2) and (yf1 <= cy <= yf2)

def run_ocr_na_imagem(img_path):
    """
    Roda o Tesseract OCR na imagem, retornando uma lista de dicionários:
    [
      {
        "text": "Certificado",
        "bbox": [x1, y1, x2, y2],   # em pixels
      },
      ...
    ]
    As coordenadas vêm de (left, top, right, bottom).
    """
    image = Image.open(img_path)

    # Se necessário, aponte o caminho do executável do Tesseract:
    # pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

    # image_to_data retorna colunas: level, page_num, block_num, ...
    data = pytesseract.image_to_data(image, output_type=pytesseract.Output.DICT)

    tokens = []
    n_boxes = len(data['text'])
    for i in range(n_boxes):
        text = data['text'][i].strip()
        conf = int(data['conf'][i])
        if text == "" or conf < 0:
            continue

        x = data['left'][i]
        y = data['top'][i]
        w = data['width'][i]
        h = data['height'][i]
        x1, y1 = x, y
        x2, y2 = x + w, y + h

        tokens.append({
            "text": text,
            "bbox": [x1, y1, x2, y2]
        })
    return tokens

# %%
def build_dataset_from_reports(reports_dir, iou_threshold=0.5, use_center=False):
    """
    Percorre uma estrutura de dois níveis:
      1. Empresa (ex.: 'Control Union', 'Food Chain ID')
      2. Relatório (subpasta, ex.: 'Relatorio_A'), 
         onde existe 1 JSON e várias páginas .jpg.

    Para cada relatório, carrega o JSON (com as anotações de campos),
    roda OCR nas imagens e gera um arquivo .jsonl rotulado.
    """

    # 1) Percorrer cada pasta de EMPRESA
    for empresa_dir in Path(reports_dir).iterdir():
        if not empresa_dir.is_dir():
            continue  # ignora se não for diretório
        print(f"== Empresa: {empresa_dir.name}")

        # 2) Dentro de cada empresa, percorrer as subpastas de RELATÓRIOS
        for relatorio_dir in sorted(empresa_dir.iterdir()):
            if not relatorio_dir.is_dir():
                continue  # pula se não for diretório

            print(f"   >> Relatório: {relatorio_dir.name}")
            
            # Procurar arquivo JSON dentro do relatório
            json_files = list(relatorio_dir.glob("*.json"))
            if len(json_files) == 0:
                print(f"   [AVISO] Nenhum JSON encontrado em '{relatorio_dir.name}'. Pulando.")
                continue
            if len(json_files) > 1:
                print(f"   [AVISO] Mais de um JSON encontrado em '{relatorio_dir.name}'. Usando o primeiro.")
            json_file = json_files[0]

            # Carregar as anotações do JSON
            annotations = load_json(json_file)

            # Dicionário para armazenar tokens OCR por página
            ocr_results = {}  # { "page_1.jpg": [ {text, bbox, label}, ... ] }

            # Localizar as imagens (.jpg) do relatório
            image_files = sorted(relatorio_dir.glob("*.jpg"))
            if not image_files:
                print(f"   [AVISO] Não há arquivos .jpg em '{relatorio_dir.name}'. Pulando.")
                continue

            # 1) Rodar OCR em cada página e iniciar label como "O"
            for img_path in image_files:
                page_name = img_path.name  # ex.: "page_1.jpg"
                tokens_ocr = run_ocr_na_imagem(img_path)  # Função que faz OCR com pytesseract
                for t in tokens_ocr:
                    t["label"] = "O"
                ocr_results[page_name] = tokens_ocr

            # 2) Para cada campo no JSON, associar tokens do OCR
            for field_name, field_info in annotations.items():
                page_name = field_info.get("pagina")
                field_bbox = field_info.get("bbox")  # [x1, y1, x2, y2]

                if page_name not in ocr_results:
                    print(f"   [AVISO] '{page_name}' não encontrado em '{relatorio_dir.name}'. Pulando campo '{field_name}'.")
                    continue

                tokens_pagina = ocr_results[page_name]
                indices_tokens = []

                # Verificar cada token para ver se ele está dentro do bbox
                for idx, token in enumerate(tokens_pagina):
                    token_bbox = token["bbox"]
                    if use_center:
                        # se o centro do token cair dentro do bbox do campo
                        if bbox_center_in(token_bbox, field_bbox):
                            indices_tokens.append(idx)
                    else:
                        # se a IOU >= iou_threshold
                        iou_val = compute_iou(token_bbox, field_bbox)
                        if iou_val >= iou_threshold:
                            indices_tokens.append(idx)

                # Marcar tokens com B- e I-
                if len(indices_tokens) > 0:
                    indices_tokens.sort()
                    tokens_pagina[indices_tokens[0]]["label"] = f"B-{field_name}"
                    for i in indices_tokens[1:]:
                        tokens_pagina[i]["label"] = f"I-{field_name}"

            # 3) Gerar dataset final (token-level) para esse relatório
            output_path = relatorio_dir / f"{relatorio_dir.name}_labeled.jsonl"

            final_data = []
            for page_name, tokens_list in ocr_results.items():
                for token in tokens_list:
                    final_data.append({
                        "empresa": empresa_dir.name,
                        "relatorio": relatorio_dir.name,
                        "pagina": page_name,
                        "text": token["text"],
                        "bbox": token["bbox"],
                        "label": token["label"]
                    })

            # Salvar em JSON lines
            with open(output_path, "w", encoding="utf-8") as f_out:
                for item in final_data:
                    f_out.write(json.dumps(item, ensure_ascii=False) + "\n")

            print(f"   [INFO] Dataset anotado salvo em: {output_path}")

# %%
build_dataset_from_reports(PROCESSED_PDF, iou_threshold=0.5, use_center=False)
# Out:
# == Empresa: Control Union
#    >> Relatório: audit_report_rtrs101
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Control Union/audit_report_rtrs101/audit_report_rtrs101_labeled.jsonl
#    >> Relatório: audit_report_rtrs104
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs104'. Pulando.
#    >> Relatório: audit_report_rtrs105
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs105'. Pulando.
#    >> Relatório: audit_report_rtrs110
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs110'. Pulando.
#    >> Relatório: audit_report_rtrs117
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Control Union/audit_report_rtrs117/audit_report_rtrs117_labeled.jsonl
#    >> Relatório: audit_report_rtrs118
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Control Union/audit_report_rtrs118/audit_report_rtrs118_labeled.jsonl
#    >> Relatório: audit_report_rtrs119
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Control Union/audit_report_rtrs119/audit_report_rtrs119_labeled.jsonl
#    >> Relatório: audit_report_rtrs120
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Control Union/audit_report_rtrs120/audit_report_rtrs120_labeled.jsonl
#    >> Relatório: audit_report_rtrs121
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Control Union/audit_report_rtrs121/audit_report_rtrs121_labeled.jsonl
#    >> Relatório: audit_report_rtrs122
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Control Union/audit_report_rtrs122/audit_report_rtrs122_labeled.jsonl
#    >> Relatório: audit_report_rtrs125
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Control Union/audit_report_rtrs125/audit_report_rtrs125_labeled.jsonl
#    >> Relatório: audit_report_rtrs126
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Control Union/audit_report_rtrs126/audit_report_rtrs126_labeled.jsonl
#    >> Relatório: audit_report_rtrs127
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Control Union/audit_report_rtrs127/audit_report_rtrs127_labeled.jsonl
#    >> Relatório: audit_report_rtrs130
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Control Union/audit_report_rtrs130/audit_report_rtrs130_labeled.jsonl
#    >> Relatório: audit_report_rtrs132
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs132'. Pulando.
#    >> Relatório: audit_report_rtrs133
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs133'. Pulando.
#    >> Relatório: audit_report_rtrs134
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs134'. Pulando.
#    >> Relatório: audit_report_rtrs137
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs137'. Pulando.
#    >> Relatório: audit_report_rtrs139
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs139'. Pulando.
#    >> Relatório: audit_report_rtrs142
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs142'. Pulando.
#    >> Relatório: audit_report_rtrs143
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs143'. Pulando.
#    >> Relatório: audit_report_rtrs145
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs145'. Pulando.
#    >> Relatório: audit_report_rtrs148
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs148'. Pulando.
#    >> Relatório: audit_report_rtrs151
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs151'. Pulando.
#    >> Relatório: audit_report_rtrs152
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs152'. Pulando.
#    >> Relatório: audit_report_rtrs155
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs155'. Pulando.
#    >> Relatório: audit_report_rtrs156
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs156'. Pulando.
#    >> Relatório: audit_report_rtrs158
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs158'. Pulando.
#    >> Relatório: audit_report_rtrs159
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs159'. Pulando.
#    >> Relatório: audit_report_rtrs161
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs161'. Pulando.
#    >> Relatório: audit_report_rtrs162
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs162'. Pulando.
#    >> Relatório: audit_report_rtrs163
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs163'. Pulando.
#    >> Relatório: audit_report_rtrs164
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs164'. Pulando.
#    >> Relatório: audit_report_rtrs165
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs165'. Pulando.
#    >> Relatório: audit_report_rtrs166
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs166'. Pulando.
#    >> Relatório: audit_report_rtrs17
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs17'. Pulando.
#    >> Relatório: audit_report_rtrs170
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs170'. Pulando.
#    >> Relatório: audit_report_rtrs171
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs171'. Pulando.
#    >> Relatório: audit_report_rtrs175
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs175'. Pulando.
#    >> Relatório: audit_report_rtrs176
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs176'. Pulando.
#    >> Relatório: audit_report_rtrs178
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs178'. Pulando.
#    >> Relatório: audit_report_rtrs180
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs180'. Pulando.
#    >> Relatório: audit_report_rtrs181
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs181'. Pulando.
#    >> Relatório: audit_report_rtrs182
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs182'. Pulando.
#    >> Relatório: audit_report_rtrs183
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs183'. Pulando.
#    >> Relatório: audit_report_rtrs184
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs184'. Pulando.
#    >> Relatório: audit_report_rtrs186
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs186'. Pulando.
#    >> Relatório: audit_report_rtrs187
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs187'. Pulando.
#    >> Relatório: audit_report_rtrs188
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs188'. Pulando.
#    >> Relatório: audit_report_rtrs19
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs19'. Pulando.
#    >> Relatório: audit_report_rtrs190
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs190'. Pulando.
#    >> Relatório: audit_report_rtrs191
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs191'. Pulando.
#    >> Relatório: audit_report_rtrs192
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs192'. Pulando.
#    >> Relatório: audit_report_rtrs195
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs195'. Pulando.
#    >> Relatório: audit_report_rtrs196
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs196'. Pulando.
#    >> Relatório: audit_report_rtrs197
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs197'. Pulando.
#    >> Relatório: audit_report_rtrs198
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs198'. Pulando.
#    >> Relatório: audit_report_rtrs199
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs199'. Pulando.
#    >> Relatório: audit_report_rtrs201
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs201'. Pulando.
#    >> Relatório: audit_report_rtrs202
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs202'. Pulando.
#    >> Relatório: audit_report_rtrs203
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs203'. Pulando.
#    >> Relatório: audit_report_rtrs206
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs206'. Pulando.
#    >> Relatório: audit_report_rtrs207
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs207'. Pulando.
#    >> Relatório: audit_report_rtrs209
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs209'. Pulando.
#    >> Relatório: audit_report_rtrs21
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs21'. Pulando.
#    >> Relatório: audit_report_rtrs211
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs211'. Pulando.
#    >> Relatório: audit_report_rtrs212
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs212'. Pulando.
#    >> Relatório: audit_report_rtrs214
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs214'. Pulando.
#    >> Relatório: audit_report_rtrs215
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs215'. Pulando.
#    >> Relatório: audit_report_rtrs216
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs216'. Pulando.
#    >> Relatório: audit_report_rtrs217
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs217'. Pulando.
#    >> Relatório: audit_report_rtrs220
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs220'. Pulando.
#    >> Relatório: audit_report_rtrs221
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs221'. Pulando.
#    >> Relatório: audit_report_rtrs223
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs223'. Pulando.
#    >> Relatório: audit_report_rtrs224
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs224'. Pulando.
#    >> Relatório: audit_report_rtrs225
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs225'. Pulando.
#    >> Relatório: audit_report_rtrs226
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs226'. Pulando.
#    >> Relatório: audit_report_rtrs227
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs227'. Pulando.
#    >> Relatório: audit_report_rtrs229
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs229'. Pulando.
#    >> Relatório: audit_report_rtrs230
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs230'. Pulando.
#    >> Relatório: audit_report_rtrs231
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs231'. Pulando.
#    >> Relatório: audit_report_rtrs233
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs233'. Pulando.
#    >> Relatório: audit_report_rtrs237
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs237'. Pulando.
#    >> Relatório: audit_report_rtrs238
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs238'. Pulando.
#    >> Relatório: audit_report_rtrs239
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs239'. Pulando.
#    >> Relatório: audit_report_rtrs24
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs24'. Pulando.
#    >> Relatório: audit_report_rtrs240
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs240'. Pulando.
#    >> Relatório: audit_report_rtrs241
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs241'. Pulando.
#    >> Relatório: audit_report_rtrs244
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs244'. Pulando.
#    >> Relatório: audit_report_rtrs25
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs25'. Pulando.
#    >> Relatório: audit_report_rtrs30
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs30'. Pulando.
#    >> Relatório: audit_report_rtrs37
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs37'. Pulando.
#    >> Relatório: audit_report_rtrs38
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs38'. Pulando.
#    >> Relatório: audit_report_rtrs4
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs4'. Pulando.
#    >> Relatório: audit_report_rtrs45
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs45'. Pulando.
#    >> Relatório: audit_report_rtrs46
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs46'. Pulando.
#    >> Relatório: audit_report_rtrs52
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs52'. Pulando.
#    >> Relatório: audit_report_rtrs53
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs53'. Pulando.
#    >> Relatório: audit_report_rtrs59
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs59'. Pulando.
#    >> Relatório: audit_report_rtrs64
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs64'. Pulando.
#    >> Relatório: audit_report_rtrs65
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs65'. Pulando.
#    >> Relatório: audit_report_rtrs75
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs75'. Pulando.
#    >> Relatório: audit_report_rtrs80
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs80'. Pulando.
#    >> Relatório: audit_report_rtrs81
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs81'. Pulando.
#    >> Relatório: audit_report_rtrs82
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs82'. Pulando.
#    >> Relatório: audit_report_rtrs86
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs86'. Pulando.
#    >> Relatório: audit_report_rtrs94
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs94'. Pulando.
#    >> Relatório: audit_report_rtrs95
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs95'. Pulando.
#    >> Relatório: audit_report_rtrs97
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs97'. Pulando.
#    >> Relatório: audit_report_rtrs98
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs98'. Pulando.
#    >> Relatório: audit_report_rtrs99
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs99'. Pulando.
# == Empresa: Food Chain ID
#    >> Relatório: audit_report_rtrs1
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Food Chain ID/audit_report_rtrs1/audit_report_rtrs1_labeled.jsonl
#    >> Relatório: audit_report_rtrs106
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs106'. Pulando.
#    >> Relatório: audit_report_rtrs107
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs107'. Pulando.
#    >> Relatório: audit_report_rtrs109
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Food Chain ID/audit_report_rtrs109/audit_report_rtrs109_labeled.jsonl
#    >> Relatório: audit_report_rtrs11
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Food Chain ID/audit_report_rtrs11/audit_report_rtrs11_labeled.jsonl
#    >> Relatório: audit_report_rtrs113
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Food Chain ID/audit_report_rtrs113/audit_report_rtrs113_labeled.jsonl
#    >> Relatório: audit_report_rtrs114
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Food Chain ID/audit_report_rtrs114/audit_report_rtrs114_labeled.jsonl
#    >> Relatório: audit_report_rtrs12
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Food Chain ID/audit_report_rtrs12/audit_report_rtrs12_labeled.jsonl
#    >> Relatório: audit_report_rtrs123
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Food Chain ID/audit_report_rtrs123/audit_report_rtrs123_labeled.jsonl
#    >> Relatório: audit_report_rtrs124
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Food Chain ID/audit_report_rtrs124/audit_report_rtrs124_labeled.jsonl
#    >> Relatório: audit_report_rtrs128
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs128'. Pulando.
#    >> Relatório: audit_report_rtrs129
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs129'. Pulando.
#    >> Relatório: audit_report_rtrs131
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs131'. Pulando.
#    >> Relatório: audit_report_rtrs138
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs138'. Pulando.
#    >> Relatório: audit_report_rtrs140
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs140'. Pulando.
#    >> Relatório: audit_report_rtrs146
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs146'. Pulando.
#    >> Relatório: audit_report_rtrs147
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs147'. Pulando.
#    >> Relatório: audit_report_rtrs153
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs153'. Pulando.
#    >> Relatório: audit_report_rtrs154
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs154'. Pulando.
#    >> Relatório: audit_report_rtrs157
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs157'. Pulando.
#    >> Relatório: audit_report_rtrs160
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs160'. Pulando.
#    >> Relatório: audit_report_rtrs168
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs168'. Pulando.
#    >> Relatório: audit_report_rtrs169
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs169'. Pulando.
#    >> Relatório: audit_report_rtrs172
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs172'. Pulando.
#    >> Relatório: audit_report_rtrs173
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs173'. Pulando.
#    >> Relatório: audit_report_rtrs177
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs177'. Pulando.
#    >> Relatório: audit_report_rtrs179
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs179'. Pulando.
#    >> Relatório: audit_report_rtrs18
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs18'. Pulando.
#    >> Relatório: audit_report_rtrs189
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs189'. Pulando.
#    >> Relatório: audit_report_rtrs193
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs193'. Pulando.
#    >> Relatório: audit_report_rtrs194
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs194'. Pulando.
#    >> Relatório: audit_report_rtrs2
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs2'. Pulando.
#    >> Relatório: audit_report_rtrs20
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs20'. Pulando.
#    >> Relatório: audit_report_rtrs200
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs200'. Pulando.
#    >> Relatório: audit_report_rtrs204
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs204'. Pulando.
#    >> Relatório: audit_report_rtrs205
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs205'. Pulando.
#    >> Relatório: audit_report_rtrs213
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs213'. Pulando.
#    >> Relatório: audit_report_rtrs218
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs218'. Pulando.
#    >> Relatório: audit_report_rtrs222
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs222'. Pulando.
#    >> Relatório: audit_report_rtrs228
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs228'. Pulando.
#    >> Relatório: audit_report_rtrs232
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs232'. Pulando.
#    >> Relatório: audit_report_rtrs234
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs234'. Pulando.
#    >> Relatório: audit_report_rtrs235
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs235'. Pulando.
#    >> Relatório: audit_report_rtrs236
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs236'. Pulando.
#    >> Relatório: audit_report_rtrs29
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs29'. Pulando.
#    >> Relatório: audit_report_rtrs3
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs3'. Pulando.
#    >> Relatório: audit_report_rtrs31
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs31'. Pulando.
#    >> Relatório: audit_report_rtrs32
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs32'. Pulando.
#    >> Relatório: audit_report_rtrs43
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs43'. Pulando.
#    >> Relatório: audit_report_rtrs44
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs44'. Pulando.
#    >> Relatório: audit_report_rtrs48
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs48'. Pulando.
#    >> Relatório: audit_report_rtrs49
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs49'. Pulando.
#    >> Relatório: audit_report_rtrs5
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs5'. Pulando.
#    >> Relatório: audit_report_rtrs50
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs50'. Pulando.
#    >> Relatório: audit_report_rtrs51
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs51'. Pulando.
#    >> Relatório: audit_report_rtrs54
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs54'. Pulando.
#    >> Relatório: audit_report_rtrs6
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Food Chain ID/audit_report_rtrs6/audit_report_rtrs6_labeled.jsonl
#    >> Relatório: audit_report_rtrs60
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs60'. Pulando.
#    >> Relatório: audit_report_rtrs61
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs61'. Pulando.
#    >> Relatório: audit_report_rtrs62
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs62'. Pulando.
#    >> Relatório: audit_report_rtrs63
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs63'. Pulando.
#    >> Relatório: audit_report_rtrs66
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs66'. Pulando.
#    >> Relatório: audit_report_rtrs69
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs69'. Pulando.
#    >> Relatório: audit_report_rtrs7
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Food Chain ID/audit_report_rtrs7/audit_report_rtrs7_labeled.jsonl
#    >> Relatório: audit_report_rtrs70
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs70'. Pulando.
#    >> Relatório: audit_report_rtrs71
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs71'. Pulando.
#    >> Relatório: audit_report_rtrs72
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs72'. Pulando.
#    >> Relatório: audit_report_rtrs73
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs73'. Pulando.
#    >> Relatório: audit_report_rtrs74
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs74'. Pulando.
#    >> Relatório: audit_report_rtrs8
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs8'. Pulando.
#    >> Relatório: audit_report_rtrs91
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs91'. Pulando.
#    >> Relatório: audit_report_rtrs92
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs92'. Pulando.
#    >> Relatório: audit_report_rtrs93
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs93'. Pulando.
#    >> Relatório: audit_report_rtrs96
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs96'. Pulando.
# == Empresa: Genesis Certificações
#    >> Relatório: audit_report_rtrs102
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Genesis Certificações/audit_report_rtrs102/audit_report_rtrs102_labeled.jsonl
#    >> Relatório: audit_report_rtrs103
#    [INFO] Dataset anotado salvo em: /home/cleyton/Documentos/ProjetosGit/meu_repositorio_dissertacao/data/processed_data/organized_audit_reports/Genesis Certificações/audit_report_rtrs103/audit_report_rtrs103_labeled.jsonl
#    >> Relatório: audit_report_rtrs111
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs111'. Pulando.
#    >> Relatório: audit_report_rtrs112
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs112'. Pulando.
#    >> Relatório: audit_report_rtrs115
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs115'. Pulando.
#    >> Relatório: audit_report_rtrs116
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs116'. Pulando.
#    >> Relatório: audit_report_rtrs13
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs13'. Pulando.
#    >> Relatório: audit_report_rtrs135
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs135'. Pulando.
#    >> Relatório: audit_report_rtrs136
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs136'. Pulando.
#    >> Relatório: audit_report_rtrs14
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs14'. Pulando.
#    >> Relatório: audit_report_rtrs141
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs141'. Pulando.
#    >> Relatório: audit_report_rtrs144
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs144'. Pulando.
#    >> Relatório: audit_report_rtrs149
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs149'. Pulando.
#    >> Relatório: audit_report_rtrs15
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs15'. Pulando.
#    >> Relatório: audit_report_rtrs150
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs150'. Pulando.
#    >> Relatório: audit_report_rtrs16
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs16'. Pulando.
#    >> Relatório: audit_report_rtrs174
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs174'. Pulando.
#    >> Relatório: audit_report_rtrs208
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs208'. Pulando.
#    >> Relatório: audit_report_rtrs22
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs22'. Pulando.
#    >> Relatório: audit_report_rtrs26
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs26'. Pulando.
#    >> Relatório: audit_report_rtrs27
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs27'. Pulando.
#    >> Relatório: audit_report_rtrs33
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs33'. Pulando.
#    >> Relatório: audit_report_rtrs34
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs34'. Pulando.
#    >> Relatório: audit_report_rtrs35
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs35'. Pulando.
#    >> Relatório: audit_report_rtrs36
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs36'. Pulando.
#    >> Relatório: audit_report_rtrs39
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs39'. Pulando.
#    >> Relatório: audit_report_rtrs40
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs40'. Pulando.
#    >> Relatório: audit_report_rtrs41
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs41'. Pulando.
#    >> Relatório: audit_report_rtrs42
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs42'. Pulando.
#    >> Relatório: audit_report_rtrs47
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs47'. Pulando.
#    >> Relatório: audit_report_rtrs55
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs55'. Pulando.
#    >> Relatório: audit_report_rtrs56
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs56'. Pulando.
#    >> Relatório: audit_report_rtrs57
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs57'. Pulando.
#    >> Relatório: audit_report_rtrs58
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs58'. Pulando.
#    >> Relatório: audit_report_rtrs76
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs76'. Pulando.
#    >> Relatório: audit_report_rtrs77
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs77'. Pulando.
#    >> Relatório: audit_report_rtrs78
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs78'. Pulando.
#    >> Relatório: audit_report_rtrs79
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs79'. Pulando.
#    >> Relatório: audit_report_rtrs83
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs83'. Pulando.
#    >> Relatório: audit_report_rtrs84
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs84'. Pulando.
#    >> Relatório: audit_report_rtrs88
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs88'. Pulando.
#    >> Relatório: audit_report_rtrs89
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs89'. Pulando.
#    >> Relatório: audit_report_rtrs9
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs9'. Pulando.
#    >> Relatório: audit_report_rtrs90
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs90'. Pulando.
# == Empresa: Bureau Veritas
#    >> Relatório: audit_report_rtrs10
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs10'. Pulando.
#    >> Relatório: audit_report_rtrs100
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs100'. Pulando.
#    >> Relatório: audit_report_rtrs167
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs167'. Pulando.
#    >> Relatório: audit_report_rtrs185
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs185'. Pulando.
#    >> Relatório: audit_report_rtrs210
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs210'. Pulando.
#    >> Relatório: audit_report_rtrs23
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs23'. Pulando.
# == Empresa: Cert ID
#    >> Relatório: audit_report_rtrs242
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs242'. Pulando.
#    >> Relatório: audit_report_rtrs243
#    [AVISO] Nenhum JSON encontrado em 'audit_report_rtrs243'. Pulando.

# %%
dataset_path = ORGANIZED_PDF / 'Control Union' / 'audit_report_rtrs101' / 'audit_report_rtrs101_labeled.jsonl'

with open(dataset_path, "r", encoding="utf-8") as f:
    for line in f:
        record = json.loads(line.strip())
        print(record)
# Out:
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '-', 'bbox': [186, 126, 283, 219], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'CONTROLUNION', 'bbox': [313, 122, 782, 202], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Relatério', 'bbox': [293, 283, 418, 307], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'de', 'bbox': [428, 283, 460, 307], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Resumo', 'bbox': [471, 285, 580, 307], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Publico', 'bbox': [591, 283, 690, 307], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'RTRS', 'bbox': [169, 368, 236, 391], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Padrao', 'bbox': [247, 367, 342, 391], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'de', 'bbox': [352, 367, 384, 391], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Produgao', 'bbox': [395, 367, 524, 396], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'de', 'bbox': [534, 367, 566, 391], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Soja', 'bbox': [576, 368, 632, 396], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Responsavel', 'bbox': [644, 367, 813, 396], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Organismo', 'bbox': [88, 426, 162, 440], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'de', 'bbox': [167, 426, 184, 437], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Certificacdo', 'bbox': [188, 426, 269, 440], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Associacao', 'bbox': [88, 446, 163, 460], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Control', 'bbox': [168, 446, 218, 457], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Union', 'bbox': [223, 446, 263, 457], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Certificates', 'bbox': [269, 446, 346, 457], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '(Contato:', 'bbox': [84, 457, 147, 487], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '[Eugénio', 'bbox': [368, 466, 421, 480], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Svolinski', 'bbox': [426, 466, 482, 477], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Junior', 'bbox': [487, 466, 528, 477], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'www.controlunion.com/certifications', 'bbox': [368, 485, 621, 499], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'certificationbr@controlunion.com', 'bbox': [368, 507, 598, 520], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Cerquality', 'bbox': [91, 561, 232, 590], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Consultoria', 'bbox': [241, 561, 397, 585], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'em', 'bbox': [408, 568, 449, 585], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Sustentabilidade', 'bbox': [459, 561, 691, 585], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'e', 'bbox': [700, 568, 715, 584], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Certificacdo', 'bbox': [725, 561, 886, 590], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'LTDA.', 'bbox': [92, 606, 169, 627], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Grupo', 'bbox': [179, 605, 265, 633], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '|', 'bbox': [275, 606, 280, 627], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '(Contato:', 'bbox': [84, 659, 147, 692], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Ismael', 'bbox': [368, 671, 410, 682], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Carlos', 'bbox': [415, 671, 456, 682], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Trevisan', 'bbox': [460, 671, 516, 682], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'E-mail:', 'bbox': [89, 679, 134, 712], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'ismael', 'bbox': [368, 680, 410, 712], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'trevisan@cerquality.com.br', 'bbox': [412, 691, 603, 705], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '[Cédigo', 'bbox': [88, 711, 135, 726], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'do', 'bbox': [139, 712, 157, 723], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'certificado:', 'bbox': [161, 712, 238, 723], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'IRTRS-CUC-AGR-COC-0048,', 'bbox': [368, 712, 539, 723], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'VValidade', 'bbox': [88, 731, 148, 743], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'do', 'bbox': [152, 732, 170, 743], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'certificado:', 'bbox': [174, 731, 251, 743], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '[01/03/2021', 'bbox': [367, 731, 446, 745], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'a', 'bbox': [451, 735, 458, 743], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '28/02/2026', 'bbox': [463, 731, 542, 745], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Localizagao', 'bbox': [89, 753, 165, 768], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'das', 'bbox': [170, 754, 193, 765], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'unidades', 'bbox': [198, 754, 260, 765], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'dentro', 'bbox': [265, 754, 311, 765], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'do', 'bbox': [316, 754, 333, 765], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'J', 'bbox': [368, 764, 373, 775], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'ads', 'bbox': [376, 764, 419, 775], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'do', 'bbox': [424, 764, 440, 775], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Maranhdo,', 'bbox': [446, 764, 518, 777], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Bahia', 'bbox': [524, 764, 559, 775], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'e', 'bbox': [562, 749, 568, 785], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Piaut', 'bbox': [577, 763, 609, 775], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '-', 'bbox': [614, 770, 617, 772], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Brasil', 'bbox': [623, 764, 658, 775], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'lescopo:', 'bbox': [88, 778, 141, 789], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '[Avaliagao', 'bbox': [84, 806, 153, 839], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Data', 'bbox': [368, 818, 399, 829], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'da', 'bbox': [404, 818, 420, 829], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'ditimas', 'bbox': [425, 818, 475, 829], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'auditorias', 'bbox': [480, 818, 549, 829], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '(Avaliacdo', 'bbox': [88, 838, 153, 852], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'principal', 'bbox': [158, 837, 217, 852], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '26/01/2021', 'bbox': [368, 837, 446, 851], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '03/09/2022;', 'bbox': [367, 860, 450, 874], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '11/10/22;', 'bbox': [457, 860, 522, 875], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '17/10/22/;', 'bbox': [528, 860, 600, 875], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '18/10/22;', 'bbox': [606, 860, 671, 874], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '19/10/22;', 'bbox': [677, 860, 742, 875], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '21/10/2022;', 'bbox': [748, 860, 831, 874], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Cae', 'bbox': [89, 872, 217, 883], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '24/11/22;', 'bbox': [368, 882, 434, 896], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '27/12/22;', 'bbox': [439, 882, 505, 896], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '24/01/23;', 'bbox': [511, 882, 576, 896], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '25/01/23', 'bbox': [582, 882, 643, 896], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'e', 'bbox': [649, 886, 656, 894], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '26/01/23', 'bbox': [661, 882, 722, 896], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '22', 'bbox': [88, 905, 103, 916], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'monitoramento', 'bbox': [108, 905, 217, 916], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '[32', 'bbox': [88, 926, 103, 937], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'monitoramento', 'bbox': [108, 926, 217, 937], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '42', 'bbox': [88, 946, 103, 957], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'monitoramento', 'bbox': [108, 946, 217, 957], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'ROUND', 'bbox': [501, 1145, 685, 1184], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'TABLE', 'bbox': [702, 1145, 858, 1183], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'ON', 'bbox': [499, 1193, 546, 1216], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'RESPONSIBLE', 'bbox': [562, 1193, 780, 1216], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'SOY', 'bbox': [794, 1193, 856, 1216], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'RTRS.REPO-AGR.FO1', 'bbox': [85, 1331, 208, 1341], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'BR', 'bbox': [213, 1331, 227, 1341], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'v7.5', 'bbox': [232, 1331, 257, 1341], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Aprovado:', 'bbox': [84, 1351, 143, 1364], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '11/04/2023', 'bbox': [152, 1350, 222, 1363], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Resumo', 'bbox': [448, 1350, 495, 1360], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Publico', 'bbox': [500, 1350, 543, 1360], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': 'Pagina', 'bbox': [828, 1350, 867, 1363], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_1.jpg', 'text': '1/63', 'bbox': [872, 1349, 905, 1362], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': '5.10', 'bbox': [282, 176, 310, 187], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Todas', 'bbox': [367, 176, 407, 187], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'as', 'bbox': [411, 179, 425, 187], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'areas', 'bbox': [430, 176, 465, 187], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'vizinhas', 'bbox': [470, 176, 522, 187], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'utilizam', 'bbox': [528, 176, 579, 187], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': '0', 'bbox': [585, 179, 592, 187], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'mesmo', 'bbox': [598, 179, 646, 187], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'tipo', 'bbox': [651, 177, 676, 190], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [682, 176, 697, 187], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'sistema', 'bbox': [702, 176, 752, 187], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [758, 176, 774, 187], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'producao.', 'bbox': [779, 176, 846, 190], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': '5.11', 'bbox': [282, 359, 310, 370], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': '[As', 'bbox': [367, 336, 383, 347], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'sementes', 'bbox': [387, 337, 451, 347], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'compradas', 'bbox': [456, 336, 530, 350], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'séo', 'bbox': [535, 336, 557, 347], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'oriundas', 'bbox': [562, 336, 620, 347], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [625, 336, 641, 347], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'fontes', 'bbox': [645, 336, 687, 347], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'legalmente', 'bbox': [693, 336, 767, 350], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'conhecidas,', 'bbox': [772, 336, 850, 349], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'conforme', 'bbox': [368, 358, 432, 369], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'evidenciado', 'bbox': [437, 358, 517, 369], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'nas', 'bbox': [523, 361, 545, 369], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Notas', 'bbox': [550, 358, 588, 369], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Fiscais', 'bbox': [593, 358, 635, 369], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [640, 358, 655, 369], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'compra', 'bbox': [660, 361, 710, 372], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [716, 358, 732, 369], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'sementes', 'bbox': [737, 359, 801, 369], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'apresentadas', 'bbox': [368, 380, 458, 394], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'na', 'bbox': [463, 383, 477, 391], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'auditoria.', 'bbox': [483, 380, 547, 391], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': '4.4', 'bbox': [282, 541, 301, 552], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'JOs', 'bbox': [368, 497, 384, 508], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Requisitos', 'bbox': [389, 497, 457, 511], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Gerais', 'bbox': [462, 497, 504, 508], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'do', 'bbox': [509, 497, 525, 508], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Sistema', 'bbox': [530, 497, 581, 508], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [587, 497, 603, 508], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Cadeia', 'bbox': [607, 497, 651, 508], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [657, 497, 673, 508], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Custédia', 'bbox': [678, 497, 735, 508], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'esto', 'bbox': [740, 497, 776, 508], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'sendo', 'bbox': [781, 497, 821, 508], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'cumpridos.', 'bbox': [368, 519, 438, 533], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'As', 'bbox': [447, 519, 462, 530], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'fazendas', 'bbox': [467, 519, 526, 530], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'esto', 'bbox': [530, 519, 566, 530], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'treinadas', 'bbox': [571, 519, 633, 530], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'e', 'bbox': [638, 522, 645, 530], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'adequadas', 'bbox': [650, 519, 723, 533], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'para', 'bbox': [729, 522, 757, 533], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'comercializar', 'bbox': [762, 519, 851, 530], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'soja', 'bbox': [856, 522, 882, 533], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'certificada', 'bbox': [368, 541, 437, 552], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'através', 'bbox': [442, 540, 491, 552], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'da', 'bbox': [496, 541, 511, 552], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'cadeia', 'bbox': [516, 541, 558, 552], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [564, 541, 580, 552], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'custédia', 'bbox': [585, 541, 640, 552], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'e', 'bbox': [646, 544, 653, 552], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'pela', 'bbox': [658, 541, 685, 555], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'plataforma', 'bbox': [691, 541, 764, 555], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [769, 541, 785, 552], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'lcomercializacao', 'bbox': [368, 563, 474, 577], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [479, 563, 495, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'créditos', 'bbox': [500, 563, 553, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'centralizada', 'bbox': [558, 563, 639, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'no', 'bbox': [645, 566, 661, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Gestor', 'bbox': [666, 563, 710, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'do', 'bbox': [715, 563, 731, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Grupo.', 'bbox': [736, 563, 781, 577], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Nao', 'bbox': [787, 563, 813, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'ocorre', 'bbox': [818, 566, 861, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'o', 'bbox': [866, 566, 874, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'manuseio', 'bbox': [368, 587, 432, 595], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [437, 584, 453, 595], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'soja', 'bbox': [458, 584, 484, 598], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'cultivadas', 'bbox': [489, 584, 556, 595], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'por', 'bbox': [561, 587, 583, 598], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'terceiros.', 'bbox': [588, 584, 650, 595], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': '2.1', 'bbox': [282, 724, 301, 735], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'As', 'bbox': [367, 702, 383, 713], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Notas', 'bbox': [388, 702, 426, 713], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Fiscais', 'bbox': [431, 702, 473, 713], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'sero', 'bbox': [478, 702, 514, 713], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'emitidas', 'bbox': [519, 702, 575, 713], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'com', 'bbox': [580, 705, 608, 713], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'as', 'bbox': [613, 705, 626, 713], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'declarages', 'bbox': [631, 702, 710, 716], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'RTRS.', 'bbox': [716, 702, 751, 713], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Até', 'bbox': [756, 702, 779, 713], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'o', 'bbox': [784, 705, 791, 713], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'momento', 'bbox': [797, 703, 862, 713], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'nao', 'bbox': [867, 702, 891, 713], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'houve', 'bbox': [368, 723, 408, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'venda', 'bbox': [413, 723, 453, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [458, 723, 474, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'soja', 'bbox': [479, 723, 505, 737], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'fisica', 'bbox': [510, 723, 543, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'certificada.', 'bbox': [548, 723, 622, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Nao', 'bbox': [628, 723, 653, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': '¢', 'bbox': [658, 722, 665, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'utilizado', 'bbox': [671, 723, 727, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'documento', 'bbox': [732, 723, 809, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'separado,', 'bbox': [814, 723, 879, 737], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'apenas', 'bbox': [368, 748, 415, 759], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'as', 'bbox': [420, 748, 433, 756], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Notas', 'bbox': [438, 745, 476, 756], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Fiscais.', 'bbox': [482, 745, 527, 756], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': '|Anexo', 'bbox': [88, 884, 131, 895], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'I:', 'bbox': [129, 875, 144, 905], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Requisitos', 'bbox': [149, 884, 220, 898], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Cadeia', 'bbox': [225, 884, 270, 895], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'ide', 'bbox': [88, 906, 104, 917], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Custédia', 'bbox': [109, 906, 168, 917], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'para', 'bbox': [174, 909, 204, 920], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': '2.2', 'bbox': [282, 907, 301, 918], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'produtores', 'bbox': [89, 928, 165, 942], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': ']O', 'bbox': [364, 852, 372, 883], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'grupo', 'bbox': [382, 865, 421, 876], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'ira', 'bbox': [427, 862, 442, 873], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'fazer', 'bbox': [447, 862, 480, 873], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'comercializacao', 'bbox': [485, 862, 592, 876], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [597, 862, 612, 873], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'créditos,', 'bbox': [617, 862, 674, 875], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'via', 'bbox': [680, 865, 697, 873], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'plataforma', 'bbox': [703, 862, 776, 876], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'RTRS', 'bbox': [782, 862, 814, 873], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [819, 862, 835, 873], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'lcomercializacdo.', 'bbox': [368, 884, 478, 898], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'As', 'bbox': [483, 884, 498, 895], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'fazendas', 'bbox': [507, 884, 566, 895], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'informaram', 'bbox': [575, 884, 654, 895], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'que', 'bbox': [659, 887, 683, 898], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'vo', 'bbox': [688, 884, 711, 895], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'manter', 'bbox': [717, 885, 765, 895], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'os', 'bbox': [770, 887, 784, 895], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'registros', 'bbox': [789, 884, 846, 898], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'e', 'bbox': [851, 887, 858, 895], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'passar', 'bbox': [368, 909, 410, 920], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'ao', 'bbox': [415, 909, 430, 917], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'gestor', 'bbox': [435, 907, 477, 920], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'do', 'bbox': [482, 906, 498, 917], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'grupo', 'bbox': [503, 909, 542, 920], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'para', 'bbox': [548, 909, 576, 920], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'elaboragao', 'bbox': [581, 905, 655, 920], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'da', 'bbox': [661, 906, 676, 917], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'planilha', 'bbox': [682, 906, 733, 920], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'com', 'bbox': [739, 909, 766, 917], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'os', 'bbox': [771, 909, 785, 917], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'resumos', 'bbox': [791, 909, 847, 917], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'anuais', 'bbox': [368, 931, 410, 939], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'dos', 'bbox': [415, 928, 438, 939], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'volumes', 'bbox': [443, 928, 499, 939], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [503, 928, 519, 939], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'soja', 'bbox': [524, 928, 550, 942], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'certificada', 'bbox': [555, 928, 624, 939], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'fornecida', 'bbox': [630, 928, 693, 939], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'aos', 'bbox': [698, 931, 720, 939], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'consumidores.', 'bbox': [725, 928, 822, 939], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Até', 'bbox': [827, 928, 850, 939], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': '0', 'bbox': [855, 931, 863, 939], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'momento', 'bbox': [368, 950, 433, 960], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'ndo', 'bbox': [438, 949, 462, 960], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'houve', 'bbox': [468, 949, 508, 960], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'a', 'bbox': [513, 952, 519, 960], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'comercializacao.', 'bbox': [525, 949, 635, 963], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': '2.3', 'bbox': [282, 1089, 301, 1100], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': '|Até', 'bbox': [367, 1067, 390, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'o', 'bbox': [395, 1070, 402, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'momento', 'bbox': [408, 1068, 473, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'nao', 'bbox': [478, 1067, 502, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'houve', 'bbox': [508, 1067, 548, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'a', 'bbox': [553, 1070, 559, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'comercializacao', 'bbox': [565, 1067, 671, 1081], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'do', 'bbox': [676, 1067, 693, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'produto', 'bbox': [698, 1067, 752, 1081], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'fisico,', 'bbox': [757, 1066, 794, 1080], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'a', 'bbox': [800, 1070, 806, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'organizaco|', 'bbox': [812, 1067, 892, 1081], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'possui', 'bbox': [368, 1088, 409, 1102], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'todos', 'bbox': [414, 1088, 452, 1099], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'os', 'bbox': [457, 1091, 471, 1099], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'registros', 'bbox': [476, 1089, 533, 1102], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'atualizados,', 'bbox': [538, 1088, 617, 1101], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'incluindo', 'bbox': [623, 1088, 684, 1099], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'os', 'bbox': [689, 1091, 703, 1099], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'requisites', 'bbox': [708, 1088, 773, 1102], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'aplicaveis', 'bbox': [778, 1088, 842, 1102], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'a', 'bbox': [847, 1091, 853, 1099], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'cadeia', 'bbox': [368, 1110, 410, 1121], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'de', 'bbox': [415, 1110, 431, 1121], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'custédia.', 'bbox': [436, 1110, 496, 1121], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'RTRS.REPO-AGR.FO1', 'bbox': [85, 1331, 208, 1341], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'BR', 'bbox': [213, 1331, 227, 1341], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'v7.5', 'bbox': [232, 1331, 257, 1341], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Aprovado:', 'bbox': [84, 1351, 143, 1364], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': '11/04/2023', 'bbox': [152, 1350, 222, 1363], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Resumo', 'bbox': [448, 1349, 495, 1359], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Publico', 'bbox': [500, 1349, 543, 1359], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_10.jpg', 'text': 'Pagina', 'bbox': [821, 1349, 859, 1362], 'label': 'O'}
# ...
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'Estocolmo', 'bbox': [651, 541, 720, 552], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'e', 'bbox': [725, 544, 732, 552], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'Roterda', 'bbox': [738, 541, 789, 552], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'foi', 'bbox': [795, 541, 811, 552], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'lencontrada.', 'bbox': [368, 563, 448, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'Nao', 'bbox': [454, 563, 480, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'foi', 'bbox': [485, 563, 501, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'evidenciado', 'bbox': [506, 563, 587, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': '0', 'bbox': [592, 566, 599, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'uso', 'bbox': [605, 566, 627, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'de', 'bbox': [632, 563, 648, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'Paraquat', 'bbox': [653, 563, 713, 577], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'nas', 'bbox': [719, 566, 740, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'fazendas', 'bbox': [745, 562, 804, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'do', 'bbox': [809, 563, 825, 574], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'escopo', 'bbox': [830, 566, 877, 577], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'de', 'bbox': [368, 584, 383, 595], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'certificacao.', 'bbox': [388, 584, 469, 598], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': '5.7', 'bbox': [282, 724, 301, 735], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'Existe', 'bbox': [368, 723, 406, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': '0', 'bbox': [411, 726, 418, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'uso', 'bbox': [424, 726, 446, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'de', 'bbox': [451, 723, 467, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'agentes', 'bbox': [472, 724, 524, 737], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'de', 'bbox': [529, 723, 545, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'controle', 'bbox': [550, 723, 605, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'biolégico', 'bbox': [611, 723, 670, 737], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'nas', 'bbox': [671, 713, 698, 744], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'fazendas', 'bbox': [702, 713, 754, 744], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'do', 'bbox': [766, 723, 782, 734], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'grupo.', 'bbox': [787, 726, 830, 737], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': '5.8', 'bbox': [282, 907, 302, 918], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': '|Apresentado', 'bbox': [367, 873, 453, 887], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'metodologia', 'bbox': [459, 873, 542, 887], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'destinadas', 'bbox': [548, 873, 631, 884], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'a', 'bbox': [618, 863, 630, 894], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'identificar', 'bbox': [637, 873, 704, 884], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'e', 'bbox': [709, 876, 716, 884], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'monitorar', 'bbox': [721, 874, 788, 884], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'novas', 'bbox': [794, 876, 831, 884], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'pragas', 'bbox': [837, 876, 880, 887], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'e', 'bbox': [885, 876, 892, 884], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'lespécies', 'bbox': [368, 895, 424, 909], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'invasoras', 'bbox': [429, 895, 491, 906], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'introduzidas,', 'bbox': [496, 894, 582, 908], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'ou', 'bbox': [588, 898, 603, 906], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'grandes', 'bbox': [609, 895, 662, 909], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'surtos', 'bbox': [667, 896, 707, 906], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'de', 'bbox': [712, 895, 728, 906], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'pragas', 'bbox': [734, 898, 777, 909], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'existentes.', 'bbox': [782, 896, 853, 906], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'Nao', 'bbox': [859, 895, 884, 906], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'houve', 'bbox': [368, 917, 408, 928], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'incidéncias', 'bbox': [414, 917, 487, 928], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'de', 'bbox': [492, 917, 507, 928], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'novas', 'bbox': [513, 920, 551, 928], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'pragas', 'bbox': [556, 920, 599, 931], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'que', 'bbox': [604, 920, 629, 931], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'nao', 'bbox': [634, 917, 658, 928], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'estejam', 'bbox': [663, 917, 715, 931], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'identificadas,', 'bbox': [721, 916, 809, 930], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'conforme', 'bbox': [815, 917, 879, 928], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'registros', 'bbox': [368, 939, 425, 952], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'apresentados.', 'bbox': [430, 938, 524, 952], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': '5.9', 'bbox': [282, 1089, 301, 1100], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'Foram', 'bbox': [368, 1067, 410, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'apresentados', 'bbox': [415, 1067, 506, 1081], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'procedimentos', 'bbox': [511, 1067, 612, 1081], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'de', 'bbox': [617, 1067, 632, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'controle', 'bbox': [637, 1067, 693, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'de', 'bbox': [698, 1067, 714, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'deriva', 'bbox': [719, 1067, 759, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'para', 'bbox': [765, 1070, 793, 1081], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'o', 'bbox': [799, 1070, 806, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'uso', 'bbox': [812, 1070, 834, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'de', 'bbox': [839, 1067, 855, 1078], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'agroquimicos', 'bbox': [368, 1088, 457, 1102], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'préximo', 'bbox': [463, 1088, 518, 1102], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'a', 'bbox': [523, 1091, 529, 1099], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'areas', 'bbox': [534, 1088, 570, 1099], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'povoadas', 'bbox': [575, 1088, 638, 1102], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'ou', 'bbox': [643, 1091, 659, 1099], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'corpos', 'bbox': [665, 1091, 709, 1102], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'd’égua,', 'bbox': [714, 1088, 763, 1102], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'bem', 'bbox': [769, 1088, 797, 1099], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'como', 'bbox': [802, 1091, 839, 1099], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'os', 'bbox': [844, 1091, 858, 1099], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'ldemais', 'bbox': [368, 1110, 415, 1121], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'cuidados', 'bbox': [420, 1110, 479, 1121], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'na', 'bbox': [484, 1113, 499, 1121], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'aplicacao', 'bbox': [505, 1110, 567, 1124], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'de', 'bbox': [572, 1110, 588, 1121], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'agrotéxicos.', 'bbox': [592, 1109, 673, 1124], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'RTRS.REPO-AGR.FO1', 'bbox': [85, 1331, 208, 1341], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'BR', 'bbox': [213, 1331, 227, 1341], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'v7.5', 'bbox': [232, 1331, 257, 1341], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'Aprovado:', 'bbox': [84, 1351, 143, 1364], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': '11/04/2023', 'bbox': [152, 1350, 222, 1363], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'Resumo', 'bbox': [448, 1349, 495, 1359], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'Publico', 'bbox': [500, 1349, 543, 1359], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': 'Pagina', 'bbox': [828, 1349, 849, 1362], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': '9', 'bbox': [868, 1349, 878, 1359], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': '/', 'bbox': [882, 1348, 887, 1361], 'label': 'O'}
# {'empresa': 'Control Union', 'relatorio': 'audit_report_rtrs101', 'pagina': 'page_9.jpg', 'text': '63', 'bbox': [892, 1349, 905, 1359], 'label': 'O'}
